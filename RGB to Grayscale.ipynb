# %% [markdown]
# **Converting RGB images into Grayscale image**

# %%
import os
from PIL import Image

def rgb_to_grayscale(rgb_image):
    # Convert RGB image to grayscale
    grayscale_image = rgb_image.convert("L")
    return grayscale_image

def convert_rgb_to_grayscale(input_dir, output_dir):
    # Create output directory if it doesn't exist
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
    
    # Iterate over each file in the input directory
    for filename in os.listdir(input_dir):
        if filename.endswith(".jpg") or filename.endswith(".jpeg") or filename.endswith(".png"):
            # Open the RGB image
            rgb_image = Image.open(os.path.join(input_dir, filename))
            
            # Convert RGB image to grayscale
            grayscale_image = rgb_to_grayscale(rgb_image)
            
            # Save grayscale image to output directory
            grayscale_image.save(os.path.join(output_dir, filename))
            
            print(f"Converted {filename} to grayscale and saved to {output_dir}")

# Paths
input_dir = r"C:\Users\zed\Dataset\Multipie_to_check\frontal"
output_dir = r"C:\Users\zed\Dataset\Grayscale_Multipie_1000\frontal"

# Convert RGB images to grayscale and save them
convert_rgb_to_grayscale(input_dir, output_dir)
# Out:
# Converted 120_01_01_051_03_crop_128.png to grayscale and saved to C:\Users\zed\Dataset\Grayscale_Multipie_1000\frontal
# Converted 120_01_02_051_03_crop_128.png to grayscale and saved to C:\Users\zed\Dataset\Grayscale_Multipie_1000\frontal
# Converted 121_01_01_051_03_crop_128.png to grayscale and saved to C:\Users\zed\Dataset\Grayscale_Multipie_1000\frontal
# Converted 121_01_02_051_03_crop_128.png to grayscale and saved to C:\Users\zed\Dataset\Grayscale_Multipie_1000\frontal
# Converted 122_01_01_051_03_crop_128.png to grayscale and saved to C:\Users\zed\Dataset\Grayscale_Multipie_1000\frontal
# Converted 122_01_02_051_03_crop_128.png to grayscale and saved to C:\Users\zed\Dataset\Grayscale_Multipie_1000\frontal
# Converted 123_01_01_051_03_crop_128.png to grayscale and saved to C:\Users\zed\Dataset\Grayscale_Multipie_1000\frontal
# Converted 123_01_02_051_03_crop_128.png to grayscale and saved to C:\Users\zed\Dataset\Grayscale_Multipie_1000\frontal
# ...
